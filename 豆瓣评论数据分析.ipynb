# %%
import sqlite3
import pandas as pd
import jieba
import pyecharts
from pyecharts.charts import WordCloud
from pyecharts import options as opts

# %%
con=sqlite3.connect('douban_comment_data.db')
comment_data=pd.read_sql_query('select * from comment;',con)
comment_data.head(5)
# Out:
#      ID                 TIME   MOVIEID RATING  \
# 0  4264  2015-06-10 02:45:06  10440138      1
# 1  4265  2015-06-10 10:39:36  10440138      2
# 2  4266  2015-06-10 19:33:11  10440138      2
# 3  4267  2015-06-10 13:22:27  10440138      1
# 4  4268  2015-06-16 14:01:42  10440138      1
#
#                                              CONTENT CREATOR  \
# 0  弱到爆…剧情、氛围烘托、表演、服化道、特效，统统弱到爆！女主和哥哥转折超级无力，给女主默默烫...      身似
# 1                     傻逼电影，看在怀旧的份儿上两星半不能更多了……一蟹不如一蟹呀     Ent
# 2  这片存在的意义难道就是告诉我们22年过去了，人类连在商业片方面都处于停滞不前，甚至倒退的状况...  有意识的贱民
# 3                                           史诗级暴虐烂片。    亿万露电
# 4                            什么jb玩意儿。。。。。。如此反智。今时今日。   Marni
#
#               ADD_TIME
# 0  2018-01-05 15:05:06
# 1  2018-01-05 15:05:06
# 2  2018-01-05 15:05:06
# 3  2018-01-05 15:05:06
# 4  2018-01-05 15:05:06

# %%
movie_comment_counts=comment_data['MOVIEID'].value_counts()
movie_comment_counts=pd.DataFrame({
    'movie_id':movie_comment_counts.index,
    'comment_counts':movie_comment_counts.values
})
movie_comment_counts.head(5)
# Out:
#    movie_id  comment_counts
# 0   1292222            1780
# 1   1292052            1040
# 2  10485647            1000
# 3   1291545            1000
# 4  24860563            1000

# %%
movie_data=pd.read_excel('douban_movie_data.xlsx')
movie_data.head(5)
# Out:
#                                         电影名        评分  评价人数  \
# 0            "ExtremeChampionshipWrestling"  (评价人数不足)   NaN
# 1                   "TheXFiles"SE6.15Monday       9.4  52.0
# 2  "WWEMondayNightRAW"Episodedated11Decembe  (评价人数不足)   NaN
# 3  "WWEMondayNightRAW"Episodedated11June200  (评价人数不足)   NaN
# 4  "WWEMondayNightRAW"Episodedated13Novembe  (评价人数不足)   NaN
#
#                                           链接                   时间  \
# 0  https://movie.douban.com/subject/1963120/  2006-06-13 00:00:00
# 1  https://movie.douban.com/subject/3158584/  1999-02-28 00:00:00
# 2  https://movie.douban.com/subject/1957739/  2006-12-11 00:00:00
# 3  https://movie.douban.com/subject/2136118/  2007-06-11 00:00:00
# 4  https://movie.douban.com/subject/1957743/  2006-11-13 00:00:00
#
#                                                   演员
# 0                                                 []
# 1  ['大卫·杜楚尼', '吉莲·安德森', '美国', 'Kim Manners', 'Arg...
# 2                                                 []
# 3                                     ['Kevin Dunn']
# 4                                                 []

# %%
def get_comments(movie_id):
    comments=comment_data[comment_data['MOVIEID']==movie_id]['CONTENT']
。但是直到看完，依然感受不到该有的9.5甚至9分。这如同“阿甘正传”。因此，它得到2星。\n还成，60分\n比不上绿里奇迹 难怪输给阿甘正传 我又来拉平均分了.....\n大仲马活着的话一定会打官司\n生活或许不完美，但得正直的活着\n不关电影的事,只因为是老师给看得\n自作聪明\n煽情过度了，嗯～真的不是很好看，捧这么高是灞陵那些觉得不好看的人，让他们歪曲自己的喜好。爬下水道辛苦了，两星\n不太明白这部电影为什么评价这么高……\n说实话我没你们这么好的层次，这部电影究竟好在哪，电影该有的跌宕剧情也没有，就光讲个人生自由，越个狱就这么高分。还不如看越狱去呢。一分只是为了拉低一点，差不多三分吧\n过于戏剧化而来阐释生活就显得无力\n分太高了吧，已经打动不了我\n美化华尔街投行人员的电影 ...

# %%
FILTER_WORDS = ['知道','影评','影片','小编','没有','一个','\n','good','is','thing','这个','就是','什么','真的','of',
'我们','最后','一部','the','片子','这么','那么','不是','还是','时候','觉得','电影','但是','hope','Hope','best','因为','只是','故事','看过','豆瓣','maybe']

# %%
movie_id='1292052'
keyword_counts=pd.Series(list(jieba.cut(get_comments(movie_id))))
keyword_counts=keyword_counts[keyword_counts.str.len()>1]
keyword_counts=keyword_counts[~keyword_counts.str.contains('|'.join(FILTER_WORDS))]
keyword_counts=keyword_counts.value_counts()[:20]
keyword_counts
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/84/bfc6dx6n44g_jhx71r9mp6280000gn/T/jieba.cache
# Loading model cost 0.761 seconds.
# Prefix dict has been built successfully.
# 希望     137
# 自由     112
# 经典      96
# 这部      91
# 喜欢      81
# 自己      74
# 感觉      69
# 越狱      65
# 救赎      55
# 监狱      54
# 好看      52
# 安迪      49
# 励志      41
# 肖申克     35
# 震撼      33
# 生活      31
# 东西      31
# 现在      29
# 看到      29
# 人生      29
# dtype: int64

# %%
wordcloud=WordCloud()
wordcloud.add(
"",
zip(keyword_counts.index.tolist(),keyword_counts.values.tolist())
)
wordcloud.set_global_opts(title_opts=opts.TitleOpts(title="最热门的20个评论关键词"))
wordcloud.render('./hottest_keywords.html')
# Out:
# '/Users/xusanliu/python数据分析基础/hottest_keywords.html'

# %%
def get_keywords(movie_id):
    keyword_counts=pd.Series(list(jieba.cut(get_comments(movie_id))))
    keyword_counts=keyword_counts[keyword_counts.str.len()>1]
    keyword_counts=keyword_counts[~keyword_counts.str.contains('|'.join(FILTER_WORDS))]
    keyword_counts=keyword_counts[:20]
    return keyword_counts

# %%
def keywords_wordcloud(movie_id):
    keyword_counts=get_keywords(movie_id)
    wordcloud=WordCloud()
    wordcloud.add(
    "",
    zip(keyword_counts.index.tolist(),keyword_counts.values.tolist())
    )
    wordcloud.set_global_opts(title_opts=opts.TitleOpts(title="最热门的20个评论关键词"))
    wordcloud.render('./hottest_keywords.html')
